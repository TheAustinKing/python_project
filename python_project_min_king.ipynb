# %%
import pandas as pd
myDF = pd.read_csv(r'data\steam.csv')

# %%
myDF.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# ...

# %%
myDF = pd.read_csv(r'data\steam.csv',usecols=[1,2,4,5,9,12,13,17])

# %%
myDF.head()
# Out:
#                         name release_date         developer publisher  genres  \
# 0             Counter-Strike   2000-11-01             Valve     Valve  Action
# 1      Team Fortress Classic   1999-04-01             Valve     Valve  Action
# 2              Day of Defeat   2003-05-01             Valve     Valve  Action
# 3         Deathmatch Classic   2001-06-01             Valve     Valve  Action
# 4  Half-Life: Opposing Force   1999-11-01  Gearbox Software     Valve  Action
#
#    positive_ratings  negative_ratings  price
# 0            124534              3339   7.19
# 1              3318               633   3.99
# 2              3416               398   3.99
# 3              1273               267   3.99
# 4              5250               288   3.99

# %%
myDF.head()
# Out:
#                     name release_date developer publisher  genres  \
# 0           Steve Austin   11/26/2019       gbc       gbc  action
# 1         Counter-Strike    11/1/2000     Valve     Valve  Action
# 2  Team Fortress Classic     4/1/1999     Valve     Valve  Action
# 3          Day of Defeat     5/1/2003     Valve     Valve  Action
# 4     Deathmatch Classic     6/1/2001     Valve     Valve  Action
#
#    positive_ratings  negative_ratings  price
# 0                 1                 1   1.00
# 1            124534              3339   7.19
# 2              3318               633   3.99
# 3              3416               398   3.99
# 4              1273               267   3.99

# %%
myDF = pd.read_csv(r'data\steam.csv',usecols=[1,2,4,5,9,12,13,17],names=['name','release_date','developer','publisher','genres','positive_ratings','negative_ratings','price'],skiprows=2)
myDF.head()
# Out:
#                         name release_date         developer publisher  genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    positive_ratings  negative_ratings  price
# 0            124534              3339   7.19
# 1              3318               633   3.99
# 2              3416               398   3.99
# 3              1273               267   3.99
# 4              5250               288   3.99

# %%
type(myDF)
# Out:
# pandas.core.frame.DataFrame

# %%
myDF['price'].head()
# Out:
# 0    7.19
# 1    3.99
# 2    3.99
# 3    3.99
# 4    3.99
# Name: price, dtype: float64

# %%
myDF.price.head()
# Out:
# 0    7.19
# 1    3.99
# 2    3.99
# 3    3.99
# 4    3.99
# Name: price, dtype: float64

# %%
type(myDF.price.head())
# Out:
# pandas.core.series.Series

# %%
myDF[['name','price']].head()
# Out:
#                         name  price
# 0             Counter-Strike   7.19
# 1      Team Fortress Classic   3.99
# 2              Day of Defeat   3.99
# 3         Deathmatch Classic   3.99
# 4  Half-Life: Opposing Force   3.99

# %%
myDF['DevPub'] = myDF['developer'] + ', '+myDF['publisher']
myDF.head()
# Out:
#                         name release_date         developer publisher  genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    positive_ratings  negative_ratings  price                   DevPub
# 0            124534              3339   7.19             Valve, Valve
# 1              3318               633   3.99             Valve, Valve
# 2              3416               398   3.99             Valve, Valve
# 3              1273               267   3.99             Valve, Valve
# 4              5250               288   3.99  Gearbox Software, Valve

# %%
myDF['Total_ratings'] = myDF['positive_ratings']+myDF['negative_ratings']
myDF.head()
# Out:
#                         name release_date         developer publisher  genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    positive_ratings  negative_ratings  price                   DevPub  \
# 0            124534              3339   7.19             Valve, Valve
# 1              3318               633   3.99             Valve, Valve
# 2              3416               398   3.99             Valve, Valve
# 3              1273               267   3.99             Valve, Valve
# 4              5250               288   3.99  Gearbox Software, Valve
#
#        Ratio  Total_ratings
# 0  37.296795         127873
# ...

# %%
myDF.describe()
# Out:
#        positive_ratings  negative_ratings         price         Ratio  \
# count      2.707500e+04      27075.000000  27075.000000  2.707500e+04
# mean       1.000559e+03        211.027147      6.078193           inf
# std        1.898872e+04       4284.938531      7.874922           NaN
# min        0.000000e+00          0.000000      0.000000  0.000000e+00
# 25%        6.000000e+00          2.000000      1.690000  1.400000e+00
# 50%        2.400000e+01          9.000000      3.990000  3.172414e+00
# 75%        1.260000e+02         42.000000      7.190000  8.425544e+00
# max        2.644404e+06     487076.000000    421.990000           inf
#
#        Total_ratings
# count   2.707500e+04
# mean    1.211586e+03
# std     2.242909e+04
# min     1.000000e+00
# 25%     1.000000e+01
# 50%     3.600000e+01
# 75%     1.760000e+02
# max     3.046717e+06

# %%
myDF.describe
# Out:
# <bound method NDFrame.describe of                                    name release_date  \
# 0                        Counter-Strike    11/1/2000
# 1                 Team Fortress Classic     4/1/1999
# 2                         Day of Defeat     5/1/2003
# 3                    Deathmatch Classic     6/1/2001
# 4             Half-Life: Opposing Force    11/1/1999
# 5                              Ricochet    11/1/2000
# 6                             Half-Life    11/8/1998
# 7        Counter-Strike: Condition Zero     3/1/2004
# 8                 Half-Life: Blue Shift     6/1/2001
# 9                           Half-Life 2   11/16/2004
# 10               Counter-Strike: Source    11/1/2004
# 11                    Half-Life: Source     6/1/2004
# 12                Day of Defeat: Source    7/12/2010
# 13              Half-Life 2: Deathmatch    11/1/2004
# 14              Half-Life 2: Lost Coast   10/27/2005
# 15         Half-Life Deathmatch: Source     5/1/2006
# ...

# %%
myDF.shape
# Out:
# (27075, 11)

# %%
myDF.dtypes
# Out:
# name                 object
# release_date         object
# developer            object
# publisher            object
# genres               object
# positive_ratings      int64
# negative_ratings      int64
# price               float64
# DevPub               object
# Ratio               float64
# Total_ratings         int64
# dtype: object

# %%
myDF.describe(include=['object'])
# Out:
#                name release_date        developer       publisher  \
# count         27075        27075            27075           27075
# unique        27033         2619            17112           14353
# top     Dark Matter    7/13/2018  Choice of Games  Big Fish Games
# freq              3           64               94             212
#
#               genres                            DevPub
# count          27075                             27075
# unique          1552                             18268
# top     Action;Indie  Choice of Games, Choice of Games
# freq            1852                                94

# %%
myDF.rename(columns={'name':'Title'}).head()
# Out:
#                        Title release_date         developer publisher  genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    positive_ratings  negative_ratings  price                   DevPub  \
# 0            124534              3339   7.19             Valve, Valve
# 1              3318               633   3.99             Valve, Valve
# 2              3416               398   3.99             Valve, Valve
# 3              1273               267   3.99             Valve, Valve
# 4              5250               288   3.99  Gearbox Software, Valve
#
#        Ratio  Total_ratings
# 0  37.296795         127873
# ...

# %%
myDF.head()
# Out:
#                         name release_date         developer publisher  genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    positive_ratings  negative_ratings  price                   DevPub  \
# 0            124534              3339   7.19             Valve, Valve
# 1              3318               633   3.99             Valve, Valve
# 2              3416               398   3.99             Valve, Valve
# 3              1273               267   3.99             Valve, Valve
# 4              5250               288   3.99  Gearbox Software, Valve
#
#        Ratio  Total_ratings
# 0  37.296795         127873
# ...

# %%
myDF.rename(columns={'name':'Title'},inplace=True)
myDF.head()
# Out:
#                        Title release_date         developer publisher  genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    positive_ratings  negative_ratings  price                   DevPub  \
# 0            124534              3339   7.19             Valve, Valve
# 1              3318               633   3.99             Valve, Valve
# 2              3416               398   3.99             Valve, Valve
# 3              1273               267   3.99             Valve, Valve
# 4              5250               288   3.99  Gearbox Software, Valve
#
#        Ratio  Total_ratings
# 0  37.296795         127873
# ...

# %%
col_names=['Name','Release Date','Developer','Publisher','Genres','Positive Ratings','Negative Ratings','Price','DevPub','Ratio','Total Ratings']
myDF.columns=col_names
myDF.head()
# Out:
#                         Name Release Date         Developer Publisher  Genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    Positive Ratings  Negative Ratings  Price                   DevPub  \
# 0            124534              3339   7.19             Valve, Valve
# 1              3318               633   3.99             Valve, Valve
# 2              3416               398   3.99             Valve, Valve
# 3              1273               267   3.99             Valve, Valve
# 4              5250               288   3.99  Gearbox Software, Valve
#
#        Ratio  Total Ratings
# 0  37.296795         127873
# ...

# %%
myDF.columns=myDF.columns.str.replace(' ','_')
myDF.head()
# Out:
#                         Name Release_Date         Developer Publisher  Genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    Positive_Ratings  Negative_Ratings  Price                   DevPub  \
# 0            124534              3339   7.19             Valve, Valve
# 1              3318               633   3.99             Valve, Valve
# 2              3416               398   3.99             Valve, Valve
# 3              1273               267   3.99             Valve, Valve
# 4              5250               288   3.99  Gearbox Software, Valve
#
#        Ratio  Total_Ratings
# 0  37.296795         127873
# ...

# %%
myDF.drop(['DevPub','Total_Ratings'],axis=1,inplace=True)
myDF.head()
# Out:
#                         Name Release_Date         Developer Publisher  Genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    Positive_Ratings  Negative_Ratings  Price
# 0            124534              3339   7.19
# 1              3318               633   3.99
# 2              3416               398   3.99
# 3              1273               267   3.99
# 4              5250               288   3.99

# %%
myDF.drop([2,4])
# Out:
#                                    Name Release_Date  \
# 0                        Counter-Strike    11/1/2000
# 1                 Team Fortress Classic     4/1/1999
# 3                    Deathmatch Classic     6/1/2001
# 5                              Ricochet    11/1/2000
# 6                             Half-Life    11/8/1998
# 7        Counter-Strike: Condition Zero     3/1/2004
# 8                 Half-Life: Blue Shift     6/1/2001
# 9                           Half-Life 2   11/16/2004
# 10               Counter-Strike: Source    11/1/2004
# 11                    Half-Life: Source     6/1/2004
# 12                Day of Defeat: Source    7/12/2010
# 13              Half-Life 2: Deathmatch    11/1/2004
# 14              Half-Life 2: Lost Coast   10/27/2005
# 15         Half-Life Deathmatch: Source     5/1/2006
# 16             Half-Life 2: Episode One     6/1/2006
# 17                               Portal   10/10/2007
# 18             Half-Life 2: Episode Two   10/10/2007
# ...

# %%
myDF.head()
# Out:
#                         Name Release_Date         Developer Publisher  Genres  \
# 0             Counter-Strike    11/1/2000             Valve     Valve  Action
# 1      Team Fortress Classic     4/1/1999             Valve     Valve  Action
# 2              Day of Defeat     5/1/2003             Valve     Valve  Action
# 3         Deathmatch Classic     6/1/2001             Valve     Valve  Action
# 4  Half-Life: Opposing Force    11/1/1999  Gearbox Software     Valve  Action
#
#    Positive_Ratings  Negative_Ratings  Price
# 0            124534              3339   7.19
# 1              3318               633   3.99
# 2              3416               398   3.99
# 3              1273               267   3.99
# 4              5250               288   3.99

# %%
myDF.Price.sort_values()
# Out:
# 5881       0.00
# 14473      0.00
# 23674      0.00
# 10215      0.00
# 17121      0.00
# 4064       0.00
# 4068       0.00
# 17123      0.00
# 4073       0.00
# 14454      0.00
# 14451      0.00
# 17132      0.00
# 14445      0.00
# 23676      0.00
# 23646      0.00
# 23643      0.00
# 10198      0.00
# 23639      0.00
# 14441      0.00
# 23633      0.00
# 19745      0.00
# 12257      0.00
# 19746      0.00
# 23622      0.00
# 17142      0.00
# 4123       0.00
# 4131       0.00
# 19743      0.00
# 23612      0.00
# 19735      0.00
#           ...
# 5384      60.99
# 14826     60.99
# 3950      60.99
# 5672      60.99
# 1854      60.99
# 3836      60.99
# 9295      60.99
# 18269     62.99
# 23709     69.99
# 1904      69.99
# 12517     74.99
# 12212     75.99
# 13053     75.99
# 2049      75.99
# 18503     78.99
# 1988      78.99
# 18745     79.99
# 1102      95.99
# 7696      98.99
# 13061    114.99
# 10624    154.99
# 10910    154.99
# 17126    154.99
# 25568    154.99
# ...

# %%
myDF.sort_values('Price')
# Out:
#                                                     Name Release_Date  \
# 5881                                              Viridi    8/19/2015
# 14473                       Extra Terrestrial Perception    6/13/2017
# 23674                                       AXIOM SOCCER    4/11/2019
# 10215                              Aussie Sports VR 2016     3/5/2019
# 17121                                    Defense Clicker   10/31/2017
# 4064                            Battlegrounds of Eldhelm   10/22/2014
# 4068                            Gems of War - Puzzle RPG   11/20/2014
# 17123                                           Slapshot     3/8/2019
# 4073                            Avalon Lords: Dawn Rises    4/28/2016
# 14454                             Adolescent Santa Claus    6/30/2018
# 14451                               The Flaws of Gravity     5/5/2017
# 17132                                A Boy and His Beard     2/9/2018
# ...

# %%
myDF.sort_values('Price',inplace=True)
myDF.head()
# Out:
#                                Name Release_Date  \
# 5881                         Viridi    8/19/2015
# 14473  Extra Terrestrial Perception    6/13/2017
# 23674                  AXIOM SOCCER    4/11/2019
# 10215         Aussie Sports VR 2016     3/5/2019
# 17121               Defense Clicker   10/31/2017
#
#                                              Developer              Publisher  \
# 5881   Zoe Vartanian;Badru;Isa Hutchinson;Michael Bell        Ice Water Games
# 14473                                 Try This At Home       Try This At Home
# 23674                            Earthbound Games Ltd.  Earthbound Games Ltd.
# 10215                                      Reload Labs            Reload Labs
# 17121                               Albatros Softworks     Albatros Softworks
#
#                                                   Genres  Positive_Ratings  \
# 5881                Casual;Free to Play;Indie;Simulation              5524
# ...

# %%
myDF.sort_values('Price').sort_values('Positive_Ratings',ascending=False)
# Out:
#                                    Name Release_Date  \
# 25     Counter-Strike: Global Offensive    8/21/2012
# 22                               Dota 2     7/9/2013
# 19                      Team Fortress 2   10/10/2007
# 12836     PLAYERUNKNOWN'S BATTLEGROUNDS   12/21/2017
# 121                         Garry's Mod   11/29/2006
# 2478                 Grand Theft Auto V    4/13/2015
# 1467                           PAYDAY 2    8/13/2013
# 3362                           Unturned     7/7/2017
# 1120                           Terraria    5/16/2011
# 21                        Left 4 Dead 2   11/19/2009
# 5235    Tom Clancy's Rainbow Six® Siege    12/1/2015
# 2031                     Rocket League®     7/7/2015
# 1025        The Elder Scrolls V: Skyrim   11/10/2011
# 1634                           Warframe    3/25/2013
# 2016                               Rust     2/8/2018
# 2964          The Witcher® 3: Wild Hunt    5/18/2015
# 1596             Euro Truck Simulator 2   10/12/2012
# ...

# %%
myDF[(myDF.Price >=25)&(myDF.Price<=35)]
# Out:
#                                                     Name Release_Date  \
# 5489                                           rFactor 2   11/12/2015
# 2902                             Assassin's Creed® Unity   12/19/2014
# 5824                               Champions of Anteria™    8/30/2016
# 2838                                         The Council    3/13/2018
# 184               Trackmania United Forever Star Edition    4/16/2008
# 1512                Rocksmith® 2014 Edition - Remastered    10/4/2016
# 8765                                              Steep™    12/2/2016
# 1255                                          Rocksmith™   10/18/2012
# 8189         Might and Magic: Heroes VII – Trial by Fire     8/4/2016
# 7958                                       State of Mind    8/15/2018
# 123                                 RACE - The WTCC Game   11/24/2006
# 2999                       Deponia: The Complete Journey     7/8/2014
# ...

# %%
myDF[(myDF.Price>=25)&(myDF.Price<=35)].sort_values('Price')
# Out:
#                                                   Name Release_Date  \
# 5489                                         rFactor 2   11/12/2015
# 19145        Leisure Suit Larry - Wet Dreams Don't Dry    11/7/2018
# 1802                                         The Crew™   12/19/2014
# 1398                  South Park™: The Stick of Truth™     3/6/2014
# 13390                                    Hunt Showdown    2/22/2018
# 1832                                       Watch_Dogs™    5/26/2014
# 891           Silent Hunter 5®: Battle of the Atlantic     3/1/2010
# 3149                                        Far Cry® 4    12/1/2014
# 2999                     Deponia: The Complete Journey     7/8/2014
# 123                               RACE - The WTCC Game   11/24/2006
# 12937                            Insurgency: Sandstorm   12/12/2018
# 8189       Might and Magic: Heroes VII – Trial by Fire     8/4/2016
# 7958                                     State of Mind    8/15/2018
# ...

# %%
myDF[(myDF.Price>=25)&(myDF.Price<=35)][{'Name','Price'}]
# Out:
#                                                     Name  Price
# 5489                                           rFactor 2  25.79
# 2902                             Assassin's Creed® Unity  25.99
# 5824                               Champions of Anteria™  25.99
# 2838                                         The Council  25.99
# 184               Trackmania United Forever Star Edition  25.99
# 1512                Rocksmith® 2014 Edition - Remastered  25.99
# 8765                                              Steep™  25.99
# 1255                                          Rocksmith™  25.99
# 8189         Might and Magic: Heroes VII – Trial by Fire  25.99
# 7958                                       State of Mind  25.99
# 123                                 RACE - The WTCC Game  25.99
# 2999                       Deponia: The Complete Journey  25.99
# 3149                                          Far Cry® 4  25.99
# 891             Silent Hunter 5®: Battle of the Atlantic  25.99
# ...

# %%
myDF[(myDF.Price>=25)&(myDF.Price<=35)&(myDF.Publisher=='Ubisoft')][{'Name','Price','Publisher'}]
# Out:
#                                               Name  Price Publisher
# 2902                       Assassin's Creed® Unity  25.99   Ubisoft
# 5824                         Champions of Anteria™  25.99   Ubisoft
# 184         Trackmania United Forever Star Edition  25.99   Ubisoft
# 1512          Rocksmith® 2014 Edition - Remastered  25.99   Ubisoft
# 8765                                        Steep™  25.99   Ubisoft
# 1255                                    Rocksmith™  25.99   Ubisoft
# 8189   Might and Magic: Heroes VII – Trial by Fire  25.99   Ubisoft
# 3149                                    Far Cry® 4  25.99   Ubisoft
# 891       Silent Hunter 5®: Battle of the Atlantic  25.99   Ubisoft
# 1832                                   Watch_Dogs™  25.99   Ubisoft
# 1398              South Park™: The Stick of Truth™  25.99   Ubisoft
# 1802                                     The Crew™  25.99   Ubisoft
# 5879                                    Anno 2205™  33.99   Ubisoft
# ...

# %%
myDF[(myDF.Publisher=='Ubisoft') | (myDF.Publisher=='Valve') | (myDF.Publisher=='Square Enix')]
# Out:
#                                                     Name Release_Date  \
# 4317                         Might & Magic Heroes Online   11/24/2015
# 5031                                 The Settlers Online    8/19/2015
# 10907          Deus Ex: Mankind Divided™ - VR Experience    1/24/2017
# 11991                                   Deus Ex: Breach™    1/24/2017
# 2138                       Just Cause 2: Multiplayer Mod   12/16/2013
# 24173             DISSIDIA FINAL FANTASY NT Free Edition    3/12/2019
# 14933     FINAL FANTASY XV WINDOWS EDITION MOD ORGANIZER     6/7/2018
# 2952                                          Brawlhalla   10/17/2017
# 21816           The Awesome Adventures of Captain Spirit    6/25/2018
# 8407                                             The Lab     4/5/2016
# 11299                              MOBIUS FINAL FANTASY™     2/5/2017
# 268                           TrackMania Nations Forever    4/16/2008
# ...

# %%
myDF.dtypes
# Out:
# Name                 object
# Release_Date         object
# Developer            object
# Publisher            object
# Genres               object
# Positive_Ratings      int64
# Negative_Ratings      int64
# Price               float64
# dtype: object

# %%
myDF[{'Positive_Ratings','Negative_Ratings','Price'}].dtypes
# Out:
# Negative_Ratings      int64
# Price               float64
# Positive_Ratings      int64
# dtype: object
